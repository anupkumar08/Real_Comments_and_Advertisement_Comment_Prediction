# %%
#Importing Libraries
import re
import string
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.base import TransformerMixin
from sklearn.metrics import accuracy_score, plot_confusion_matrix, classification_report, confusion_matrix
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
from sklearn.svm import SVC

# %%
# !pip install wordcloud
from wordcloud import WordCloud

# %%
#Reading dataset
df = pd.read_csv("F:/ZS/Data Sets/train.csv")

# %%
#Shape of the dataset
df.shape
# Out:
# (1157, 5)

# %%
#Head of the dataset
df.head()
# Out:
#                                     COMMENT_ID           AUTHOR  \
# 0  LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU        Julius NM
# 1          z13jhp0bxqncu512g22wvzkasxmvvzjaz04  ElNino Melendez
# 2          z13fwbwp1oujthgqj04chlngpvzmtt3r3dw           GsMega
# 3          z13lfzdo5vmdi1cm123te5uz2mqig1brz04   ferleck ferles
# 4          z12avveb4xqiirsix04chxviiljryduwxg0      BeBe Burkey
#
#                   DATE                                            CONTENT  \
# 0  2013-11-07T06:20:48  Huh, anyway check out this you[tube] channel: ...
# 1  2013-11-09T08:28:43   me shaking my sexy ass on my channel enjoy ^_^ ﻿
# 2  2013-11-10T16:05:38            watch?v=vtaRGgvGtWQ   Check this out .﻿
# 3  2013-11-27T21:39:24                          Subscribe to my channel ﻿
# 4  2013-11-28T16:30:13  and u should.d check my channel and tell me wh...
#
#    CLASS
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df.interpolate(inplace=True)
df.isnull().sum()
# Out:
# COMMENT_ID      0
# AUTHOR          0
# DATE          138
# CONTENT         0
# CLASS           0
# dtype: int64

# %%
#Fill NaN values with blank space
df["DATE"] = df["DATE"].fillna(df["DATE"].mode())

df.head()
# Out:
#                                     COMMENT_ID           AUTHOR  \
# 0  LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU        Julius NM
# 1          z13jhp0bxqncu512g22wvzkasxmvvzjaz04  ElNino Melendez
# 2          z13fwbwp1oujthgqj04chlngpvzmtt3r3dw           GsMega
# 3          z13lfzdo5vmdi1cm123te5uz2mqig1brz04   ferleck ferles
# 4          z12avveb4xqiirsix04chxviiljryduwxg0      BeBe Burkey
#
#                   DATE                                            CONTENT  \
# 0  2013-11-07T06:20:48  Huh, anyway check out this you[tube] channel: ...
# 1  2013-11-09T08:28:43   me shaking my sexy ass on my channel enjoy ^_^ ﻿
# 2  2013-11-10T16:05:38            watch?v=vtaRGgvGtWQ   Check this out .﻿
# 3  2013-11-27T21:39:24                          Subscribe to my channel ﻿
# 4  2013-11-28T16:30:13  and u should.d check my channel and tell me wh...
#
#    CLASS
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df.isnull().sum()
# Out:
# COMMENT_ID    0
# AUTHOR        0
# DATE          0
# CONTENT       0
# CLASS         0
# dtype: int64

# %%
# Advertisement and Real visualization
sns.countplot(df.CLASS).set_title('Real & Advertisement')
df.groupby('CLASS').count()['CONTENT'].reset_index().sort_values(by='CONTENT',ascending=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#    CLASS  CONTENT
# 1      1      586
# 0      0      571

# %%
#Most frequent comments
print(df.CONTENT.value_counts()[:10])
# Out:
# Check out this video on YouTube:﻿                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             52
# ...

# %%
#Titles and count of Advertisement comments
print(df[df.CLASS==1].CONTENT.value_counts()[:10])
# Out:
# Check out this video on YouTube:﻿                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             52
# ...

# %%
#Comments and count of real Comments
print(df[df.CLASS==0].CONTENT.value_counts()[:10])
# Out:
# wow                                                              4
# Katy Perry - Roar (Official): http://youtu.be/CevxZvSJLk8﻿       3
# Love this song makes me wanna dance! ﻿                           3
# nice song﻿                                                       2
# everyday I&#39;m shufflin﻿                                       2
# PSY - GANGNAM STYLE (강남스타일) M/V: http://youtu.be/9bZkp7q19f0﻿    2
# awesome﻿                                                         2
# Shakira :-*                                                      2
# Nice﻿                                                            2
# I hate rap and I like this song﻿                                 1
# Name: CONTENT, dtype: int64

# %%
#Separate Advertisement and actual Comments
Advertisement_text = df[df.CLASS==1].CONTENT
actualCommentss_text = df[df.CLASS==0].CONTENT

#Advertisement comments word cloud
STOPWORDS = spacy.lang.en.stop_words.STOP_WORDS
plt.figure(figsize = (16,14))
wc = WordCloud(min_font_size = 3,  max_words = 3000 , width = 1600 , height = 800 , stopwords = STOPWORDS).generate(str(" ".join(Advertisement_text)))
plt.imshow(wc,interpolation = 'bilinear')

# %%
#Actual Advertisement wordcloud
plt.figure(figsize = (16,14))
wc = WordCloud(min_font_size = 3,  max_words = 3000 , width = 1600 , height = 800 , stopwords = STOPWORDS).generate(str(" ".join(actualCommentss_text)))
plt.imshow(wc,interpolation = 'bilinear')

# %% [markdown]
# ### Cleaning and preprocessing

# %%
import string
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
# Create our list of punctuation marks
punctuations = string.punctuation

# Create our list of stopwords
#nlp = spacy.load('en')
nlp = spacy.load("en_core_web_sm")
stop_words = spacy.lang.en.stop_words.STOP_WORDS

# Load English tokenizer, tagger, parser, NER and word vectors
parser = English()

# Creating our tokenizer function
def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    mytokens = parser(sentence)

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]

    # Removing stop words
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # return a preprocessed list of tokens
    return mytokens

# Custom transformer using spaCy
class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        # Cleaning Text
        return [clean_text(text) for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

    def get_params(self, deep=True):
        return {}

# Basic function to clean the text
def clean_text(text):
    # Removing spaces and converting text into lowercase
    return text.strip().lower()

# %%
# Splitting dataset in train and test
X_train, X_test, y_train, y_test = train_test_split(df.CONTENT, df.CLASS, test_size=0.3)

#Train-test shape
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (809,)
# (809,)
# (348,)
# (348,)

# %%
X_train
# Out:
# 224    Check out my covers I have a video coming out ...
# 751           Just gonna stand there and hear me cry ..﻿
# 842                    Check out this video on YouTube:﻿
# 449           Ahhh back when my life didn&#39;t suck...﻿
# 26     Plz subscribe to my channel and I will subscri...
#                              ...
# 151                            MANY MEMORIES...........﻿
# 89     reminds me of this song https://soundcloud.com...
# 112    People, here is a new network like FB...you re...
# 961                                        Good song:-)﻿
# 677                           Subscribe to my channel !﻿
# Name: CONTENT, Length: 809, dtype: object

# %%
# creating our bag of words
bow_vector = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,3))

# %% [markdown]
# y_train

# %%
#Support Vector Machine Classifier
# Create pipeline using Bag of Words
pipe = Pipeline([("cleaner", predictors()),
                 #('vectorizer', CountVectorizer(tokenizer = spacy_tokenizer, token_pattern=r"(?u)\b\w+\b", ngram_range=(1,3))),
                 ('vectorizer', bow_vector),
                 ('classifier', SVC())])

#Training the model.
pipe.fit(X_train,y_train)
#pipe.fit("train","Life")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ANOOPM~1\AppData\Local\Temp/ipykernel_23168/168736910.py in <module>
#       7
#       8 #Training the model.
# ----> 9 pipe.fit(X_train,y_train)
#      10 #pipe.fit("train","Life")
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     339         """
#     340         fit_params_steps = self._check_fit_params(**fit_params)
# --> 341         Xt = self._fit(X, y, **fit_params_steps)
#     342         with _print_elapsed_time('Pipeline',
#     343                                  self._log_message(len(self.steps) - 1)):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     301                 cloned_transformer = clone(transformer)
#     302             # Fit or load from cache the current transformer
# ...
